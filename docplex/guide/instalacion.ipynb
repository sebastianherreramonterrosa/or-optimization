# %% [markdown]
# **_Verificamos que Python esté agregado al PATH del sistema_**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **_Nos dirijimos a la ruta de instalación de CPLEX_**
#
# En windows sueles ser: C:\Program Files\IBM\ILOG\[CPLEX_VERSION]\python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **_Ejecutamos CMD como adiministrador y en la ruta del paso anterior y ejecutamos: python setup.py install_**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
