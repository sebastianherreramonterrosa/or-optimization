# %%
import collections

import folium
import geopy.distance
import numpy
import pandas
from ortools.constraint_solver import pywrapcp, routing_enums_pb2

# %%
df_sitios_bog = pandas.read_csv("./data/sitios-de-interes-en-bogota.csv", sep=";")
df_sitios_bog = df_sitios_bog[["Nombre", "Geo Point"]]
df_sitios_bog["Lat"] = df_sitios_bog.apply(lambda row: float(row["Geo Point"].split(",")[0]), axis=1)
df_sitios_bog["Lng"] = df_sitios_bog.apply(lambda row: float(row["Geo Point"].split(",")[1]), axis=1)
df_sitios_bog.drop("Geo Point", axis=1, inplace=True)
df_sitios_bog = df_sitios_bog.head(101)
df_sitios_bog = df_sitios_bog.drop_duplicates(subset="Nombre")
df_sitios_bog = df_sitios_bog.set_index("Nombre")
df_sitios_bog
# Out:
#                                                     Lat        Lng
# Nombre
# Escultura Nave Espacial                        4.615251 -74.071534
# Estatua Tomas Cipriano de Mosquera             4.597386 -74.076421
# Estatua Ricardo Palma                          4.602078 -74.066768
# Monumento al Almirante José Prudencio Padilla  4.625450 -74.074206
# Monumento 21 Ángeles                           4.732816 -74.075095
# ...                                                 ...        ...
# Laboratorios Spaison Ltda                      4.681562 -74.117520
# Luminex Legrand                                4.693044 -74.118457
# Doña Juana ESP SA                              4.499661 -74.143927
# Avianca                                        4.645531 -74.099483
# Notaría 14                                     4.641680 -74.072357
#
# [100 rows x 2 columns]

# %%
lat_mean = df_sitios_bog["Lat"].mean()
lng_mean = df_sitios_bog["Lng"].mean()

bogota_map = folium.Map(location=[lat_mean, lng_mean], zoom_start=12, tiles="cartodbdark_matter")
for idx, row in df_sitios_bog.iterrows():
    if idx == "Bavaria SA.":
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=5, color="yellow", fill=True, fill_color="white", fill_opacity=0.6, popup=f"{idx}").add_to(bogota_map)
    else:
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=5, color="blue", fill=True, fill_color="white", fill_opacity=0.8, popup=f"{idx}").add_to(bogota_map)

bogota_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9cfa5b3fbea8a3703171b06a8919c14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9cfa5b3fbea8a3703171b06a8919c14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9cfa5b3fbea8a3703171b06a8919c14 = L.map(
#                 &quot;map_b9cfa5b3fbea8a3703171b06a8919c14&quot;,
#                 {
#                     center: [4.641263422780065, -74.09581026774993],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9709d6fd25871d1f7b9c92d4f9108d9f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b9cfa5b3fbea8a3703171b06a8919c14);
#
#
#             var circle_marker_86dffb40860cbb9be09d5fa1aae6afb8 = L.circleMarker(
#                 [4.6152509440000795, -74.07153385099991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b9cfa5b3fbea8a3703171b06a8919c14);
#
#
#         var popup_d96e0ac5fb2fa80e53093677752adad0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fbe885d02bba31de11d85e940c7fe23 = $(`&lt;div id=&quot;html_3fbe885d02bba31de11d85e940c7fe23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Escultura Nave Espacial&lt;/div&gt;`)[0];
#                 popup_d96e0ac5fb2fa80e53093677752adad0.setContent(html_3fbe885d02bba31de11d85e940c7fe23);
#
#
#
#         circle_marker_86dffb40860cbb9be09d5fa1aae6afb8.bindPopup(popup_d96e0ac5fb2fa80e53093677752adad0)
#         ;
#
#
#
#
#             var circle_marker_84048c5ac452dbb6eb0224b83110e3db = L.circleMarker(
#                 [4.597386297000071, -74.07642138699993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b9cfa5b3fbea8a3703171b06a8919c14);
#
#
#         var popup_713c5c5629dc4865acbd25051af811e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7cb4891c4268bfaa537d57ddc14c0205 = $(`&lt;div id=&quot;html_7cb4891c4268bfaa537d57ddc14c0205&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Tomas Cipriano de Mosquera&lt;/div&gt;`)[0];
#                 popup_713c5c5629dc4865acbd25051af811e3.setContent(html_7cb4891c4268bfaa537d57ddc14c0205);
#
#
#
#         circle_marker_84048c5ac452dbb6eb0224b83110e3db.bindPopup(popup_713c5c5629dc4865acbd25051af811e3)
#         ;
#
#
#
#
#             var circle_marker_281df2a7ce6737f2335c2a299de8c295 = L.circleMarker(
#                 [4.602078094000092, -74.06676842199994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b9cfa5b3fbea8a3703171b06a8919c14);
#
#
#         var popup_e9b7629820363588bb68b86c3407ff07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53ec3b7c8eb661300424f3f06e39f403 = $(`&lt;div id=&quot;html_53ec3b7c8eb661300424f3f06e39f403&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Ricardo Palma&lt;/div&gt;`)[0];
#                 popup_e9b7629820363588bb68b86c3407ff07.setContent(html_53ec3b7c8eb661300424f3f06e39f403);
#
#
#
#         circle_marker_281df2a7ce6737f2335c2a299de8c295.bindPopup(popup_e9b7629820363588bb68b86c3407ff07)
#         ;
#
#
#
#
#             va

# %%
df_distancias = pandas.DataFrame()
for nodo1 in df_sitios_bog.index.to_list():
    for nodo2 in df_sitios_bog.index.to_list():
        df_distancias.loc[nodo1, nodo2] = round(10000 * geopy.distance.geodesic((df_sitios_bog.loc[nodo1, "Lat"], df_sitios_bog.loc[nodo1, "Lng"]), (df_sitios_bog.loc[nodo2, "Lat"], df_sitios_bog.loc[nodo2, "Lng"])).km)
df_distancias = df_distancias[df_distancias.columns].astype(int)
df_distancias.head()
# Out:
#                                                Escultura Nave Espacial  \
# Escultura Nave Espacial                                              0
# Estatua Tomas Cipriano de Mosquera                               20486
# Estatua Ricardo Palma                                            15497
# Monumento al Almirante José Prudencio Padilla                    11662
# Monumento 21 Ángeles                                            130066
#
#                                                Estatua Tomas Cipriano de Mosquera  \
# Escultura Nave Espacial                                                     20486
# Estatua Tomas Cipriano de Mosquera                                              0
# Estatua Ricardo Palma                                                       11902
# Monumento al Almirante José Prudencio Padilla                               31131
# Monumento 21 Ángeles                                                       149768
#
#                                                Estatua Ricardo Palma  \
# Escultura Nave Espacial                                        15497
# Estatua Tomas Cipriano de Mosquera                             11902
# Estatua Ricardo Palma                                              0
# Monumento al Almirante José Prudencio Padilla                  27131
# Monumento 21 Ángeles                                          144867
#
#                                                Monumento al Almirante José Prudencio Padilla  \
# Escultura Nave Espacial                                                                11662
# Estatua Tomas Cipriano de Mosquera                                                     31131
# Estatua Ricardo Palma                                                                  27131
# Monumento al Almirante José Prudencio Padilla                                              0
# Monumento 21 Ángeles                                                                  118732
#
#                                                Monumento 21 Ángeles  \
# Escultura Nave Espacial                                      130066
# Estatua Tomas Cipriano de Mosquera                           149768
# Estatua Ricardo Palma                                        144867
# Monumento al Almirante José Prudencio Padilla                118732
# Monumento 21 Ángeles                                              0
#
#                                                Museo del Oro  \
# Escultura Nave Espacial                                14812
# Estatua Tomas Cipriano de Mosquera                      7063
# Estatua Ricardo Palma                                   5677
# Monumento al Almirante José Prudencio Padilla          26212
# Monumento 21 Ángeles                                  144856
#
#                                                Instituto Caro y Cuervo  \
# Escultura Nave Espacial                                          21444
# Estatua Tomas Cipriano de Mosquera                                3227
# Estatua Ricardo Palma                                            10351
# Monumento al Almirante José Prudencio Padilla                    32568
# Monumento 21 Ángeles                                            151300
#
#                                                Palacio de San Carlos  \
# Escultura Nave Espacial                                        21095
# Estatua Tomas Cipriano de Mosquera                              2298
# Estatua Ricardo Palma                                          10695
# Monumento al Almirante José Prudencio Padilla                  32102
# Monumento 21 Ángeles                                          150828
#
#                                                Plaza Fundacional de Suba  \
# Escultura Nave Espacial                                           139701
# Estatua Tomas Cipriano de Mosquera                                159000
# Estatua Ricardo Palma                                             154763
# Monumento al Almirante José Prudencio Padilla                     128200
# Monumento 21 Ángeles                                               13258
#
#                                                Club Bellavista Colsubsidio  \
# Escultura Nave Espacial                                             234932
# Estatua Tomas Cipriano de Mosquera                                  255326
# Estatua Ricardo Palma                                               248518
# Monumento al Almirante José Prudencio Padilla                       224366
# Monumento 21 Ángeles                                                110504
#
#                                                ...  \
# Escultura Nave Espacial                        ...
# Estatua Tomas Cipriano de Mosquera             ...
# Estatua Ricardo Palma                          ...
# Monumento al Almirante José Prudencio Padilla  ...
# Monumento 21 Ángeles                           ...
#
#                                                Bavaria Dirección de Ventas Bogotá  \
# Escultura Nave Espacial                                                     22399
# Estatua Tomas Cipriano de Mosquera                                          33309
# Estatua Ricardo Palma                                                       35364
# Monumento al Almirante José Prudencio Padilla                               16993
# Monumento 21 Ángeles                                                       120835
#
#                                                Bavaria SA.  \
# Escultura Nave Espacial                              73755
# Estatua Tomas Cipriano de Mosquera                   79558
# Estatua Ricardo Palma                                85294
# Monumento al Almirante José Prudencio Padilla        67027
# Monumento 21 Ángeles                                118044
#
#                                                BEG Fábrica de Lubricantes  \
# Escultura Nave Espacial                                             44194
# Estatua Tomas Cipriano de Mosquera                                  23995
# Estatua Ricardo Palma                                               34365
# Monumento al Almirante José Prudencio Padilla                       53953
# Monumento 21 Ángeles                                               171351
#
#                                                Matadero Frigo Iberia  \
# Escultura Nave Espacial                                       144614
# Estatua Tomas Cipriano de Mosquera                            124138
# Estatua Ricardo Palma                                         131995
# Monumento al Almirante José Prudencio Padilla                 154968
# Monumento 21 Ángeles                                          272195
#
#                                                Protex SA.  \
# Escultura Nave Espacial                            134627
# Estatua Tomas Cipriano de Mosquera                 145158
# Estatua Ricardo Palma                              148552
# Monumento al Almirante José Prudencio Padilla      124967
# Monumento 21 Ángeles                               102749
#
#                                                Laboratorios Spaison Ltda  \
# Escultura Nave Espacial                                            89333
# Estatua Tomas Cipriano de Mosquera                                103653
# Estatua Ricardo Palma                                             104386
# Monumento al Almirante José Prudencio Padilla                      78484
# Monumento 21 Ángeles                                               73674
#
#                                                Luminex Legrand  \
# Escultura Nave Espacial                                 100553
# Estatua Tomas Cipriano de Mosquera                      115606
# Estatua Ricardo Palma                                   115792
# Monumento al Almirante José Prudencio Padilla            89429
# Monumento 21 Ángeles                                     65183
#
#                                                Doña Juana ESP SA  Avianca  \
# Escultura Nave Espacial                                   150970    45639
# Estatua Tomas Cipriano de Mosquera                        131492    59070
# Estatua Ricardo Palma                                     141979    60221
# Monumento al Almirante José Prudencio Padilla             159168    35774
# Monumento 21 Ángeles                                      268902   100243
#
#                                                Notaría 14
# Escultura Nave Espacial                             29240
# Estatua Tomas Cipriano de Mosquera                  49187
# Estatua Ricardo Palma                               44229
# Monumento al Almirante José Prudencio Padilla       18064
# Monumento 21 Ángeles                               100826
#
# [5 rows x 100 columns]

# %%
distance_matrix = df_distancias.values.tolist()
num_vehicles = 1
depot = 92

# %%
# Create the routing index manager.
manager = pywrapcp.RoutingIndexManager(len(distance_matrix), num_vehicles, depot)

# Create Routing Model.
routing = pywrapcp.RoutingModel(manager)


# Create and register a transit callback.
def distance_callback(from_index, to_index):
    """Returns the distance between the two nodes."""
    from_node = manager.IndexToNode(from_index)
    to_node = manager.IndexToNode(to_index)
    return distance_matrix[from_node][to_node]


transit_callback_index = routing.RegisterTransitCallback(distance_callback)

# Define cost of each arc.
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# Setting first solution heuristic.
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC

# %%
# Solve the problem.
solution = routing.SolveWithParameters(search_parameters)

# %%
# Print solution on console.
if solution:
    print("Objective: {}".format(solution.ObjectiveValue() / 10000))
    index = routing.Start(0)
    plan_output = "Route for vehicle 0:\n"
    route_distance = 0
    ruta = []
    while not routing.IsEnd(index):
        plan_output += " {} ->".format(manager.IndexToNode(index))
        ruta.append(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += " {}\n".format(manager.IndexToNode(index))
    ruta.append(manager.IndexToNode(index))
    print(plan_output)
else:
    print("No solution found!")
# Out:
# Objective: 161.4442
# Route for vehicle 0:
#  92 -> 49 -> 86 -> 30 -> 11 -> 93 -> 97 -> 12 -> 14 -> 20 -> 29 -> 40 -> 84 -> 68 -> 36 -> 48 -> 38 -> 57 -> 10 -> 44 -> 24 -> 83 -> 31 -> 55 -> 88 -> 37 -> 35 -> 81 -> 82 -> 90 -> 17 -> 61 -> 62 -> 98 -> 89 -> 91 -> 26 -> 46 -> 94 -> 15 -> 87 -> 67 -> 41 -> 96 -> 95 -> 32 -> 72 -> 71 -> 74 -> 66 -> 8 -> 4 -> 73 -> 80 -> 75 -> 9 -> 45 -> 25 -> 51 -> 13 -> 27 -> 78 -> 70 -> 42 -> 69 -> 53 -> 47 -> 23 -> 77 -> 54 -> 28 -> 76 -> 16 -> 60 -> 99 -> 79 -> 58 -> 21 -> 85 -> 19 -> 64 -> 3 -> 50 -> 59 -> 22 -> 34 -> 43 -> 0 -> 56 -> 2 -> 5 -> 6 -> 7 -> 1 -> 65 -> 33 -> 63 -> 52 -> 39 -> 18 -> 92

# %%
def get_bearing(p1, p2):
    long_diff = numpy.radians(p2.lon - p1.lon)
    lat1 = numpy.radians(p1.lat)
    lat2 = numpy.radians(p2.lat)
    x = numpy.sin(long_diff) * numpy.cos(lat2)
    y = numpy.cos(lat1) * numpy.sin(lat2) - (numpy.sin(lat1) * numpy.cos(lat2) * numpy.cos(long_diff))
    bearing = numpy.degrees(numpy.arctan2(x, y))
    if bearing < 0:
        return bearing + 360
    return bearing


def get_arrows(locations, color="black", size=4, n_arrows=3, weight_arrow=3):
    Point = collections.namedtuple("Point", field_names=["lat", "lon"])
    p1 = Point(locations[0][0], locations[0][1])
    p2 = Point(locations[1][0], locations[1][1])
    rotation = get_bearing(p1, p2) - 90
    arrow_lats = numpy.linspace(p1.lat, p2.lat, n_arrows + 2)[1 : n_arrows + 1]
    arrow_lons = numpy.linspace(p1.lon, p2.lon, n_arrows + 2)[1 : n_arrows + 1]
    arrows = []
    for points in zip(arrow_lats, arrow_lons):
        arrows.append(
            folium.RegularPolygonMarker(
                location=points,
                color=color,
                weight=weight_arrow,
                fill=True,
                fill_color=color,
                fill_opacity=1,
                number_of_sides=3,
                radius=size,
                rotation=rotation,
            )
        )
    return arrows

# %%
df_sitios_bog
# Out:
#                                                     Lat        Lng
# Nombre
# Escultura Nave Espacial                        4.615251 -74.071534
# Estatua Tomas Cipriano de Mosquera             4.597386 -74.076421
# Estatua Ricardo Palma                          4.602078 -74.066768
# Monumento al Almirante José Prudencio Padilla  4.625450 -74.074206
# Monumento 21 Ángeles                           4.732816 -74.075095
# ...                                                 ...        ...
# Laboratorios Spaison Ltda                      4.681562 -74.117520
# Luminex Legrand                                4.693044 -74.118457
# Doña Juana ESP SA                              4.499661 -74.143927
# Avianca                                        4.645531 -74.099483
# Notaría 14                                     4.641680 -74.072357
#
# [100 rows x 2 columns]

# %%
lat_mean = df_sitios_bog["Lat"].mean()
lng_mean = df_sitios_bog["Lng"].mean()

bogota_map = folium.Map(location=[lat_mean, lng_mean], zoom_start=12, tiles="cartodbdark_matter")
for idx, row in df_sitios_bog.iterrows():
    if idx == "Bavaria SA.":
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=10, color="yellow", fill=True, fill_color="white", fill_opacity=0.6, popup=idx).add_to(bogota_map)
    else:
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=5, color="blue", fill=True, fill_color="white", fill_opacity=0.8, popup=idx).add_to(bogota_map)

for i in range(len(ruta) - 1):
    coordinates = [
        df_sitios_bog.reset_index().loc[ruta[i], ["Lat", "Lng"]].values.tolist(),
        df_sitios_bog.reset_index().loc[ruta[i + 1], ["Lat", "Lng"]].values.tolist(),
    ]

    color = "gray"
    weight = 2

    pl = folium.PolyLine(coordinates, color=color, weight=weight)
    bogota_map.add_child(pl)

    arrows = get_arrows(locations=coordinates, color=color, size=2, n_arrows=1)
    for arrow in arrows:
        arrow.add_to(bogota_map)


bogota_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86a96a73fadcd1c9452e3db0f3a4a5b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86a96a73fadcd1c9452e3db0f3a4a5b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86a96a73fadcd1c9452e3db0f3a4a5b2 = L.map(
#                 &quot;map_86a96a73fadcd1c9452e3db0f3a4a5b2&quot;,
#                 {
#                     center: [4.641263422780065, -74.09581026774993],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b4769bf14c136f50fb6bcfd87b04aaa = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86a96a73fadcd1c9452e3db0f3a4a5b2);
#
#
#             var circle_marker_05de31145b787ac586ce1ec65bcee50d = L.circleMarker(
#                 [4.6152509440000795, -74.07153385099991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86a96a73fadcd1c9452e3db0f3a4a5b2);
#
#
#         var popup_de325349d5febef0990b74da0221ac9a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c7c63aff63e067a21a98d60f0c1cd0db = $(`&lt;div id=&quot;html_c7c63aff63e067a21a98d60f0c1cd0db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Escultura Nave Espacial&lt;/div&gt;`)[0];
#                 popup_de325349d5febef0990b74da0221ac9a.setContent(html_c7c63aff63e067a21a98d60f0c1cd0db);
#
#
#
#         circle_marker_05de31145b787ac586ce1ec65bcee50d.bindPopup(popup_de325349d5febef0990b74da0221ac9a)
#         ;
#
#
#
#
#             var circle_marker_c64778ebb5f707e4d6ca22e68f847d73 = L.circleMarker(
#                 [4.597386297000071, -74.07642138699993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86a96a73fadcd1c9452e3db0f3a4a5b2);
#
#
#         var popup_11803d65dcc9f989dd426039a8d823ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d294cd3a783779936dcef94ef724c9c = $(`&lt;div id=&quot;html_4d294cd3a783779936dcef94ef724c9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Tomas Cipriano de Mosquera&lt;/div&gt;`)[0];
#                 popup_11803d65dcc9f989dd426039a8d823ec.setContent(html_4d294cd3a783779936dcef94ef724c9c);
#
#
#
#         circle_marker_c64778ebb5f707e4d6ca22e68f847d73.bindPopup(popup_11803d65dcc9f989dd426039a8d823ec)
#         ;
#
#
#
#
#             var circle_marker_2513658f407c6f17001563e6bd65538f = L.circleMarker(
#                 [4.602078094000092, -74.06676842199994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86a96a73fadcd1c9452e3db0f3a4a5b2);
#
#
#         var popup_a02130d9b719ee13144c40199602b62a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd50f8d90d6b26a15a11ab57f062df5f = $(`&lt;div id=&quot;html_bd50f8d90d6b26a15a11ab57f062df5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Ricardo Palma&lt;/div&gt;`)[0];
#                 popup_a02130d9b719ee13144c40199602b62a.setContent(html_bd50f8d90d6b26a15a11ab57f062df5f);
#
#
#
#         circle_

# %%
# Create the routing index manager.
manager = pywrapcp.RoutingIndexManager(len(distance_matrix), num_vehicles, depot)

# Create Routing Model.
routing = pywrapcp.RoutingModel(manager)


# Create and register a transit callback.
def distance_callback(from_index, to_index):
    """Returns the distance between the two nodes."""
    from_node = manager.IndexToNode(from_index)
    to_node = manager.IndexToNode(to_index)
    return distance_matrix[from_node][to_node]


transit_callback_index = routing.RegisterTransitCallback(distance_callback)

# Define cost of each arc.
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)


# Setting first solution heuristic.
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
search_parameters.time_limit.seconds = 60
search_parameters.log_search = True

# %%
# Solve the problem.
solution = routing.SolveWithParameters(search_parameters)

# %%
# Print solution on console.
if solution:
    print("Objective: {}".format(solution.ObjectiveValue()/10000))
    index = routing.Start(0)
    plan_output = "Route for vehicle 0:\n"
    route_distance = 0
    ruta = []
    while not routing.IsEnd(index):
        plan_output += " {} ->".format(manager.IndexToNode(index))
        ruta.append(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += " {}\n".format(manager.IndexToNode(index))
    ruta.append(manager.IndexToNode(index))
    print(plan_output)
else:
    print("No solution found!")
# Out:
# Objective: 157.8616
# Route for vehicle 0:
#  92 -> 18 -> 39 -> 52 -> 63 -> 33 -> 65 -> 1 -> 7 -> 6 -> 5 -> 2 -> 56 -> 0 -> 43 -> 34 -> 22 -> 59 -> 50 -> 3 -> 64 -> 19 -> 85 -> 21 -> 58 -> 79 -> 28 -> 54 -> 47 -> 23 -> 77 -> 78 -> 27 -> 13 -> 51 -> 73 -> 25 -> 45 -> 80 -> 75 -> 9 -> 74 -> 66 -> 8 -> 4 -> 71 -> 72 -> 32 -> 70 -> 42 -> 69 -> 95 -> 96 -> 41 -> 67 -> 87 -> 15 -> 94 -> 46 -> 26 -> 91 -> 89 -> 98 -> 61 -> 62 -> 53 -> 16 -> 76 -> 99 -> 60 -> 17 -> 90 -> 82 -> 81 -> 35 -> 37 -> 88 -> 55 -> 31 -> 83 -> 24 -> 44 -> 10 -> 57 -> 38 -> 48 -> 36 -> 68 -> 84 -> 40 -> 29 -> 20 -> 14 -> 12 -> 97 -> 93 -> 11 -> 30 -> 86 -> 49 -> 92

# %%
lat_mean = df_sitios_bog["Lat"].mean()
lng_mean = df_sitios_bog["Lng"].mean()

bogota_map = folium.Map(location=[lat_mean, lng_mean], zoom_start=12, tiles="cartodbdark_matter")
for idx, row in df_sitios_bog.iterrows():
    if idx == "Bavaria SA.":
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=10, color="yellow", fill=True, fill_color="white", fill_opacity=0.6, popup=idx).add_to(bogota_map)
    else:
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=5, color="blue", fill=True, fill_color="white", fill_opacity=0.8, popup=idx).add_to(bogota_map)

for i in range(len(ruta) - 1):
    coordinates = [
        df_sitios_bog.reset_index().loc[ruta[i], ["Lat", "Lng"]].values.tolist(),
        df_sitios_bog.reset_index().loc[ruta[i + 1], ["Lat", "Lng"]].values.tolist(),
    ]

    color = "gray"
    weight = 2

    pl = folium.PolyLine(coordinates, color=color, weight=weight)
    bogota_map.add_child(pl)

    arrows = get_arrows(locations=coordinates, color=color, size=2, n_arrows=1)
    for arrow in arrows:
        arrow.add_to(bogota_map)


bogota_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b69082208f48b983994eaba80f9e00a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b69082208f48b983994eaba80f9e00a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b69082208f48b983994eaba80f9e00a9 = L.map(
#                 &quot;map_b69082208f48b983994eaba80f9e00a9&quot;,
#                 {
#                     center: [4.641263422780065, -74.09581026774993],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce60b900f4457f73cb277874a51b24ce = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b69082208f48b983994eaba80f9e00a9);
#
#
#             var circle_marker_e2334e5ee6a726556eaaeea02e8a966e = L.circleMarker(
#                 [4.6152509440000795, -74.07153385099991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b69082208f48b983994eaba80f9e00a9);
#
#
#         var popup_b5b64f8e1a2b4f907071546eb83e6652 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83371e2d2da786da3903b3c61b0f690a = $(`&lt;div id=&quot;html_83371e2d2da786da3903b3c61b0f690a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Escultura Nave Espacial&lt;/div&gt;`)[0];
#                 popup_b5b64f8e1a2b4f907071546eb83e6652.setContent(html_83371e2d2da786da3903b3c61b0f690a);
#
#
#
#         circle_marker_e2334e5ee6a726556eaaeea02e8a966e.bindPopup(popup_b5b64f8e1a2b4f907071546eb83e6652)
#         ;
#
#
#
#
#             var circle_marker_7daf313e18ac91e0583dbaae458c58fa = L.circleMarker(
#                 [4.597386297000071, -74.07642138699993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b69082208f48b983994eaba80f9e00a9);
#
#
#         var popup_f2805ace5293fb3c0c8eb9858c4583fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c6bb0525ed6c334a2382476a67cacb7 = $(`&lt;div id=&quot;html_9c6bb0525ed6c334a2382476a67cacb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Tomas Cipriano de Mosquera&lt;/div&gt;`)[0];
#                 popup_f2805ace5293fb3c0c8eb9858c4583fe.setContent(html_9c6bb0525ed6c334a2382476a67cacb7);
#
#
#
#         circle_marker_7daf313e18ac91e0583dbaae458c58fa.bindPopup(popup_f2805ace5293fb3c0c8eb9858c4583fe)
#         ;
#
#
#
#
#             var circle_marker_0a44471272d18776e467012fde5aabfe = L.circleMarker(
#                 [4.602078094000092, -74.06676842199994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b69082208f48b983994eaba80f9e00a9);
#
#
#         var popup_48191750da406ba917d789716e7c50fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2def0fe0d02bae0b5fe5f5b76d6b287e = $(`&lt;div id=&quot;html_2def0fe0d02bae0b5fe5f5b76d6b287e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Ricardo Palma&lt;/div&gt;`)[0];
#                 popup_48191750da406ba917d789716e7c50fa.setContent(html_2def0fe0d02bae0b5fe5f5b76d6b287e);
#
#
#
#         circle_
