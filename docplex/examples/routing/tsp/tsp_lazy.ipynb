# %%
import folium
import pandas
import collections
import numpy
import geopy.distance
import itertools
from docplex.mp.model import Model

# %%
df_sitios_bog = pandas.read_csv("./data/sitios-de-interes-en-bogota.csv", sep=";")
df_sitios_bog = df_sitios_bog[["Nombre", "Geo Point"]]
df_sitios_bog["Lat"] = df_sitios_bog.apply(lambda row: float(row["Geo Point"].split(",")[0]), axis=1)
df_sitios_bog["Lng"] = df_sitios_bog.apply(lambda row: float(row["Geo Point"].split(",")[1]), axis=1)
df_sitios_bog.drop("Geo Point", axis=1, inplace=True)
df_sitios_bog = df_sitios_bog.head(101)
df_sitios_bog = df_sitios_bog.drop_duplicates(subset="Nombre")
df_sitios_bog = df_sitios_bog.set_index("Nombre")
df_sitios_bog
# Out:
#                                                     Lat        Lng
# Nombre
# Escultura Nave Espacial                        4.615251 -74.071534
# Estatua Tomas Cipriano de Mosquera             4.597386 -74.076421
# Estatua Ricardo Palma                          4.602078 -74.066768
# Monumento al Almirante José Prudencio Padilla  4.625450 -74.074206
# Monumento 21 Ángeles                           4.732816 -74.075095
# ...                                                 ...        ...
# Laboratorios Spaison Ltda                      4.681562 -74.117520
# Luminex Legrand                                4.693044 -74.118457
# Doña Juana ESP SA                              4.499661 -74.143927
# Avianca                                        4.645531 -74.099483
# Notaría 14                                     4.641680 -74.072357
#
# [100 rows x 2 columns]

# %%
lat_mean = df_sitios_bog["Lat"].mean()
lng_mean = df_sitios_bog["Lng"].mean()

bogota_map = folium.Map(location=[lat_mean, lng_mean], zoom_start=12, tiles="cartodbdark_matter")
for idx, row in df_sitios_bog.iterrows():
    if idx == "Bavaria SA.":
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=5, color="yellow", fill=True, fill_color="white", fill_opacity=0.6, popup=f"{idx}").add_to(bogota_map)
    else:
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=5, color="blue", fill=True, fill_color="white", fill_opacity=0.8, popup=f"{idx}").add_to(bogota_map)

bogota_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bab3581d4facf3ee3fcc05594ab77cb3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bab3581d4facf3ee3fcc05594ab77cb3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bab3581d4facf3ee3fcc05594ab77cb3 = L.map(
#                 &quot;map_bab3581d4facf3ee3fcc05594ab77cb3&quot;,
#                 {
#                     center: [4.641263422780065, -74.09581026774993],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3181e407cf9d3f03460e9cc9ff37e3fc = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bab3581d4facf3ee3fcc05594ab77cb3);
#
#
#             var circle_marker_3728845ae48f36420be30a95a4333bc2 = L.circleMarker(
#                 [4.6152509440000795, -74.07153385099991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bab3581d4facf3ee3fcc05594ab77cb3);
#
#
#         var popup_d4f0227ec88f073d8c3ec8888d08f356 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_692fdd2275e8e30c52f98bde4068bae1 = $(`&lt;div id=&quot;html_692fdd2275e8e30c52f98bde4068bae1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Escultura Nave Espacial&lt;/div&gt;`)[0];
#                 popup_d4f0227ec88f073d8c3ec8888d08f356.setContent(html_692fdd2275e8e30c52f98bde4068bae1);
#
#
#
#         circle_marker_3728845ae48f36420be30a95a4333bc2.bindPopup(popup_d4f0227ec88f073d8c3ec8888d08f356)
#         ;
#
#
#
#
#             var circle_marker_ddf45959e37d362932aca545a4247fbd = L.circleMarker(
#                 [4.597386297000071, -74.07642138699993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bab3581d4facf3ee3fcc05594ab77cb3);
#
#
#         var popup_5edf9c5c9059ca7515e39f7987a4070a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c3cf2f21717f5cf82d5874a96d89102 = $(`&lt;div id=&quot;html_5c3cf2f21717f5cf82d5874a96d89102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Tomas Cipriano de Mosquera&lt;/div&gt;`)[0];
#                 popup_5edf9c5c9059ca7515e39f7987a4070a.setContent(html_5c3cf2f21717f5cf82d5874a96d89102);
#
#
#
#         circle_marker_ddf45959e37d362932aca545a4247fbd.bindPopup(popup_5edf9c5c9059ca7515e39f7987a4070a)
#         ;
#
#
#
#
#             var circle_marker_9d4b6aaa5ba9d732bf150d20a20bc1da = L.circleMarker(
#                 [4.602078094000092, -74.06676842199994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bab3581d4facf3ee3fcc05594ab77cb3);
#
#
#         var popup_44b2789703bc507f1fc1fcc2f11fc6d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_961f17c5b92ae6818ca3148d494762ab = $(`&lt;div id=&quot;html_961f17c5b92ae6818ca3148d494762ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Ricardo Palma&lt;/div&gt;`)[0];
#                 popup_44b2789703bc507f1fc1fcc2f11fc6d3.setContent(html_961f17c5b92ae6818ca3148d494762ab);
#
#
#
#         circle_marker_9d4b6aaa5ba9d732bf150d20a20bc1da.bindPopup(popup_44b2789703bc507f1fc1fcc2f11fc6d3)
#         ;
#
#
#
#
#             va

# %% [markdown]
# #### **Conjuntos**
#
# $$ \text{CLIENTES} = \{1, 2, \ldots, N\} $$
# $$ \text{NODOS} = \{0\} \cup \text{CLIENTES} $$

# %%
NODOS = df_sitios_bog.index.to_list()
CLIENTES = df_sitios_bog[df_sitios_bog.index != "Bavaria SA."].index.to_list()

# %% [markdown]
# #### **Parámetros**
#
# $$ \text{DISTANCIAS}\_{n1, n2}: \text{Distancia euclidiana entre } n1 \in \text{NODOS} \text{ y } n2 \in \text{NODOS} $$

# %%
df_distancias = pandas.DataFrame()
for nodo1 in NODOS:
    for nodo2 in NODOS:
        df_distancias.loc[nodo1, nodo2] = geopy.distance.geodesic(
            (df_sitios_bog.loc[nodo1, "Lat"], df_sitios_bog.loc[nodo1, "Lng"]), (df_sitios_bog.loc[nodo2, "Lat"], df_sitios_bog.loc[nodo2, "Lng"])
        ).km
        df_sitios_bog

# %%
model = Model("TSP")

# %% [markdown]
# #### **Variables de Decisión**
#
# $$
# x_{n1, n2} = \begin{cases}
# 1 & \text{Si el vehículo viaja de } n1 \in \text{NODOS} \text{ a } n2 \in \text{NODOS} \\
# 0 & \text{d.l.c.}
# \end{cases}
# $$
#
# $$ u\_{n} \in \mathbb{R}^{+} \text{: Carga acumulada del vehículo al llegar al nodo } n \in \text{NODOS} $$

# %%
x = model.binary_var_matrix(NODOS, NODOS, name='x')

# %% [markdown]
# #### **Función Objetivo**
#
# $$ \text{Minimizar } \sum*{n1 \in \text{NODOS}} \sum*{n2 \in \text{NODOS}} \text{DISTANCIAS}_{n1, n2} \cdot x_{n1, n2} $$

# %%
model.minimize(model.sum(df_distancias.loc[nodo1, nodo2] * x[nodo1, nodo2] for nodo1 in NODOS for nodo2 in NODOS))

# %% [markdown]
# #### **Restricciones**
#
# 1. **Prohibición de bucles:**
#    $$ \forall n \in \text{NODOS}: x\_{n, n} = 0 $$
#
# 2. **Asignación única de salidas para cada cliente:**
#    $$ \forall n1 \in \text{NODOS}: \sum*{n2 \in \text{NODOS}} x*{n1, n2} = 1 $$
#
# 3. **Asignación única de entradas para cada cliente:**
#    $$ \forall n2 \in \text{NODOS}: \sum*{n1 \in \text{NODOS}} x*{n1, n2} = 1 $$
#
# 4. **Restricciones para evitar subtours:**
#    $$ \forall \text{ ST} \subset \text{NODOS} / 2 \leq |\text{ST}| \leq |\text{NODOS}| - 2 : \sum*{n1 \in \text{NODOS}} \sum*{n2 \in \text{NODOS}} x\_{n1, n2} \leq \left | \text{ST} \right | - 1$$

# %%
for nodo in NODOS:
    model.add_constraint(x[nodo, nodo] == 0)

for nodo1 in NODOS:
    model.add_constraint(model.sum(x[nodo1, nodo2] for nodo2 in NODOS if nodo1 != nodo2) == 1)

for nodo1 in NODOS:
    model.add_constraint(model.sum(x[nodo2, nodo1] for nodo2 in NODOS if nodo1 != nodo2) == 1)

# %%
# Resolver el modelo inicialmente
solution = model.solve()

# %%
def get_tour(solution, x, n):
    tour = [0]
    while len(tour) < n:
        for j in range(n):
            if solution.get_value(x[tour[-1], j]) > 0.5:
                tour.append(j)
                break
        if tour[-1] == 0:
            break
    return tour

def get_shortest_subtour(selected_arcs):
    unvisited = NODOS[:]
    cycle = NODOS[:]
    while unvisited:
        thiscycle = []
        neighbors = unvisited
        while neighbors:
            current = neighbors[0]
            thiscycle.append(current)
            unvisited.remove(current)
            neighbors = [j for i, j in [arc for arc in selected_arcs if arc[0] == current] if j in unvisited]
        if len(thiscycle) <= len(cycle):
            cycle = thiscycle
    return cycle

# %%
while True:
    selected_arcs = [(n1, n2) for n1 in NODOS for n2 in NODOS if solution.get_value(x[n1, n2]) > 0.5]
    shortest_subtour = get_shortest_subtour(selected_arcs)

    print("\n\nSUBCICLO")
    print(shortest_subtour)
    
    if len(shortest_subtour) < len(NODOS):
        model.add_constraint(model.sum(x[i, j] + x[j, i] for i, j in itertools.combinations(shortest_subtour, 2)) <= len(shortest_subtour) - 1)
        solution = model.solve()
    else:
        break
# Out:
# SUBCICLO
# ['Matadero Frigo Iberia', 'Doña Juana ESP SA']
#
#
# SUBCICLO
# ['Chevron Texaco', 'Bavaria SA.']
#
#
# SUBCICLO
# ['Chevron Texaco', 'Avianca']
#
#
# SUBCICLO
# ['Centro Educativo Distrital La Chucua Norte', 'Centro Educativo Distrital Nueva Colombia']
#
#
# SUBCICLO
# ['Colegio Distrital Mariano Ospina Pérez', 'Laboratorios Spaison Ltda']
#
#
# SUBCICLO
# ['Colegio Distrital Magdalena Ortega de Nariño', 'Colegio Distrital Rafael Bernal Jiménez']
#
#
# SUBCICLO
# ['Instituto Geográfico Agustín Codazzi - IGAC', 'Notaría 14']
#
#
# SUBCICLO
# ['Alcaldía Local de Chapinero', 'Colegio Distrital Manuela Beltrán']
#
#
# SUBCICLO
# ['Alcaldía Local de Sumapaz', 'Munal']
#
#
# SUBCICLO
# ['Iglesia de San Agustín', 'Ministerio de Hacienda']
#
#
# SUBCICLO
# ['Iglesia Nuestra Señora de La Paz', 'Sub Estación de Policía de Muzu']
#
#
# SUBCICLO
# ['Parroquia Señor de La Buena Esperanza', 'CADE Bosa']
#
#
# SUBCICLO
# ['Parroquia Santa Cecilia', 'Estación de Bomberos de Venecia']
#
#
# SUBCICLO
# ['Iglesia Santa Juana', 'Luminex Legrand']
#
#
# SUBCICLO
# ['Parroquia Nuestra Señora de Las Lajas', 'Centro Educativo Distrital Emma Villegas de Gaitán']
#
#
# SUBCICLO
# ['Capilla La Milagrosa', 'Bavaria Dirección de Ventas Bogotá']
#
#
# SUBCICLO
# ['Iglesia La Concepción', 'Secretaria de Cultura, Recreación y Deporte']
#
#
# SUBCICLO
# ['Parroquia Santa Margarita María', 'Estación de Bomberos de Kennedy']
#
#
# SUBCICLO
# ['Iglesia La Porciúncula', 'Colegio San Felipe Neri']
#
#
# SUBCICLO
# ['Colegio San Felipe Neri', 'Colegio Distrital Rafael Bernal Jiménez']
#
#
# SUBCICLO
# ['Iglesia Jesucristo de Los Santos de Los Últimos Días', 'Estación de Bomberos Garcés Navas']
#
#
# SUBCICLO
# ['Compensar Cl 94', 'Centro Educativo Distrital Carlos Sanz de Santamaría']
#
#
# SUBCICLO
# ['UPA San Cristóbal', 'Parroquia San Juan Bosco']
#
#
# SUBCICLO
# ['Hospital Universitario Barrios Unidos Mederi', 'Iglesia de Jesucristo de los Santos de los Últimos Días']
#
#
# SUBCICLO
# ['Hospital Universitario Mayor MEDERI', 'Centro Administrativo Distrital - CAD']
#
#
# SUBCICLO
# ['Caja de Compensación Familiar Compensar', 'Edificio Ecopetrol Sede Principal']
#
#
# SUBCICLO
# ['Profamilia Quiroga', 'Centro de Ayuda Espiritual']
#
#
# SUBCICLO
# ['Hospital La Victoria III Nivel E.S.E - Sede Materno', 'Parroquia Nuestra Señora del Camen de las Cruces']
#
#
# SUBCICLO
# ['Iglesia San Cristóbal', 'Estación de Policía San Cristóbal']
#
#
# SUBCICLO
# ['Clínica Fundadores', 'Bavaria Dirección de Ventas Bogotá']
#
#
# SUBCICLO
# ['Clínica Fundadores', 'Instituto Geográfico Agustín Codazzi - IGAC']
#
#
# SUBCICLO
# ['CAMI Emaus', 'Fábrica Indubo']
#
#
# SUBCICLO
# ['CAMI San Pablo', 'Iglesia Nuestra Señora de Fontibón']
#
#
# SUBCICLO
# ['Hospital La Victoria III Nivel E.S.E.', 'Parroquia San León Magno']
#
#
# SUBCICLO
# ['Club Bellavista Colsubsidio', 'Colegio Distrital Aquileo Parra']
#
#
# SUBCICLO
# ['Instituto Caro y Cuervo', 'Palacio de San Carlos']
#
#
# SUBCICLO
# ['Clínica Federman', 'Centro Educativo Distrital Alemania']
#
#
# SUBCICLO
# ['Escultura Nave Espacial', 'Iglesia María Reina']
#
#
# SUBCICLO
# ['Parroquia Nuestra Señora de Las Lajas', 'Centro Educativo Distrital Emma Villegas de Gaitán', 'Colegio Distrital Liceo Nacional Agustín Nieto Caballero']
#
#
# SUBCICLO
# ['Liga Contra el Cáncer Seccional Bogotá', 'Estación de Policía Chapinero']
#
#
# SUBCICLO
# ['Parroquia Santa Cecilia', 'Parroquia Nuestra Señora de la Salud', 'Estación de Bomberos de Venecia']
#
#
# SUBCICLO
# ['CAMI San Pablo', 'Protex SA.', 'Iglesia Nuestra Señora de Fontibón']
#
#
# SUBCICLO
# ['Iglesia San Juan de Ávila', 'Centro Educativo Distrital Prado Pinzón']
#
#
# SUBCICLO
# ['Templo Adventista Séptimo Día', 'Colegio Distrital Mariano Ospina Pérez']
#
#
# SUBCICLO
# ['Templo Adventista Séptimo Día', 'Colegio Distrital Magdalena Ortega de Nariño', 'Colegio Distrital Mariano Ospina Pérez']
#
#
# SUBCICLO
# ['Clínica Colsubsidio Roma', 'Estación de Bomberos de Kennedy', 'Parroquia Santa Margarita María']
#
#
# SUBCICLO
# ['Hospital Bosa II Nivel E.S.E.', 'Capilla San José']
#
#
# SUBCICLO
# ['Estatua Ricardo Palma', 'Museo del Oro', 'Alcaldía Local de Santafé']
#
#
# SUBCICLO
# ['Parroquia San Irinco', 'Bavaria SA.']
#
#
# SUBCICLO
# ['Estatua Tomas Cipriano de Mosquera', 'Iglesia La Concepción', 'Secretaria de Cultura, Recreación y Deporte']
#
#
# SUBCICLO
# ['Ministerio de Defensa Nacional', 'Instituto Colombiano de Desarrollo Rural - INCODER', 'Avianca', 'Chevron Texaco']
#
#
# SUBCICLO
# ['Estatua Ricardo Palma', 'Alcaldía Local de Santafé']
#
#
# SUBCICLO
# ['Hospital La Victoria III Nivel E.S.E - Sede Materno', 'Parroquia Nuestra Señora del Camen de las Cruces', 'Iglesia de San Agustín', 'Ministerio de Hacienda']
#
#
# SUBCICLO
# ['Iglesia María Reina', 'Colegio Distrital Liceo Nacional Agustín Nieto Caballero']
#
#
# SUBCICLO
# ['Estatua Ricardo Palma', 'Museo del Oro']
#
#
# SUBCICLO
# ['Monumento al Almirante José Prudencio Padilla', 'Iglesia de Nuestra Señora de la Soledad', 'Caja de Compensación Familiar Compensar', 'Edificio Ecopetrol Sede Principal']
#
#
# SUBCICLO
# ['CAMI Emaus', 'Fábrica Indubo', 'CAMI San Pablo', 'Iglesia Nuestra Señora de Fontibón', 'Protex SA.']
#
#
# SUBCICLO
# ['Club Bellavista Colsubsidio', 'Colegio Distrital Aquileo Parra', 'Colegio Distrital Saludcoop Norte', 'UPA San Cristóbal', 'Parroquia San Juan Bosco']
#
#
# SUBCICLO
# ['Plaza Fundacional de Suba', 'Estación de Bomberos Suba']
# %%
solution.objective_value
# Out:
# 156.21552612794568

# %%
depot = "Bavaria SA."
for cliente in CLIENTES:
    if x[depot, cliente].solution_value > 0.9:
        print(f"==== Ruta ====")
        ruta = [depot, cliente]
        r = f"{depot} -> {cliente} -> "

        cliente_actual = cliente
        while x[cliente_actual, depot].solution_value < 0.9:
            for siguiente_cliente in CLIENTES:
                if x[cliente_actual, siguiente_cliente].solution_value > 0.9:
                    break
            ruta.append(siguiente_cliente)
            r += str(siguiente_cliente) + " -> "
            cliente_actual = siguiente_cliente

        ruta.append(depot)
        r += depot
        print(r)
# Out:
# ==== Ruta ====
# Bavaria SA. -> Chevron Texaco -> Avianca -> Ministerio de Defensa Nacional -> Instituto Colombiano de Desarrollo Rural - INCODER -> Centro Religioso Policía Nacional -> Clínica Federman -> Centro Educativo Distrital Alemania -> Iglesia de Jesucristo de los Santos de los Últimos Días -> Hospital Universitario Barrios Unidos Mederi -> Colegio Distrital Rafael Bernal Jiménez -> Colegio Distrital Magdalena Ortega de Nariño -> Templo Adventista Séptimo Día -> Colegio Distrital Mariano Ospina Pérez -> Laboratorios Spaison Ltda -> Luminex Legrand -> Iglesia Santa Juana -> CAMI San Pablo -> Iglesia Nuestra Señora de Fontibón -> Protex SA. -> CAMI Emaus -> Fábrica Indubo -> Estación de Bomberos Garcés Navas -> Iglesia Jesucristo de Los Santos de Los Últimos Días -> Centro Educativo Distrital Nueva Colombia -> Centro Educativo Distrital La Chucua Norte -> Monumento 21 Ángeles -> Plaza Fundacional de Suba -> Estación de Bomberos Suba -> Colegio Distrital Chorrillos -> Club Bellavista Colsubsidio -> Colegio Distrital Aquileo Parra -> Colegio Distrital Saludcoop Norte -> Parroquia San Juan Bosco -> UPA San Cristóbal -> Centro Educativo Distrital Prado Pinzón -> Iglesia San Juan de Ávila -> UPA Usaquén -> Compensar Cl 94 -> Centro Educativo Distrital Carlos Sanz de Santamaría -> Colegio San Felipe Neri -> Iglesia La Porciúncula -> Estación de Policía Chapinero -> Liga Contra el Cáncer Seccional Bogotá -> Alcaldía Local de Chapinero -> Colegio Distrital Manuela Beltrán -> Notaría 14 -> Instituto Geográfico Agustín Codazzi - IGAC -> Clínica Fundadores -> Bavaria Dirección de Ventas Bogotá -> Capilla La Milagrosa -> Hospital Universitario Mayor MEDERI -> Centro Administrativo Distrital - CAD -> Iglesia de Nuestra Señora de la Soledad -> Monumento al Almirante José Prudencio Padilla -> Caja de Compensación Familiar Compensar -> Edificio Ecopetrol Sede Principal -> Escultura Nave Espacial -> Iglesia María Reina -> Alcaldía Local de Santafé -> Estatua Ricardo Palma -> Museo del Oro -> Instituto Caro y Cuervo -> Palacio de San Carlos -> Iglesia de San Agustín -> Ministerio de Hacienda -> Estatua Tomas Cipriano de Mosquera -> Secretaria de Cultura, Recreación y Deporte -> Iglesia La Concepción -> Colegio Distrital Liceo Nacional Agustín Nieto Caballero -> Parroquia Nuestra Señora de Las Lajas -> Centro Educativo Distrital Emma Villegas de Gaitán -> Hospital La Victoria III Nivel E.S.E - Sede Materno -> Parroquia Nuestra Señora del Camen de las Cruces -> BEG Fábrica de Lubricantes -> Iglesia San Cristóbal -> Estación de Policía San Cristóbal -> Parroquia San León Magno -> Hospital La Victoria III Nivel E.S.E. -> Matadero Frigo Iberia -> Doña Juana ESP SA -> Hospital Meissen II Nivel ESE -> Hospital Tunjuelito II Nivel ESE Unidad de Medicina Interna -> Profamilia Quiroga -> Centro de Ayuda Espiritual -> Iglesia Nuestra Señora de La Paz -> Sub Estación de Policía de Muzu -> Estación de Bomberos de Venecia -> Parroquia Santa Cecilia -> Parroquia Nuestra Señora de la Salud -> Parroquia Señor de La Buena Esperanza -> CADE Bosa -> Hospital Bosa II Nivel E.S.E. -> Capilla San José -> Clínica Colsubsidio Roma -> Estación de Bomberos de Kennedy -> Parroquia Santa Margarita María -> Alcaldía Local de Sumapaz -> Munal -> Parroquia San Irinco -> Bavaria SA.

# %%
def get_bearing(p1, p2):
    long_diff = numpy.radians(p2.lon - p1.lon)
    lat1 = numpy.radians(p1.lat)
    lat2 = numpy.radians(p2.lat)
    x = numpy.sin(long_diff) * numpy.cos(lat2)
    y = numpy.cos(lat1) * numpy.sin(lat2) - (numpy.sin(lat1) * numpy.cos(lat2) * numpy.cos(long_diff))
    bearing = numpy.degrees(numpy.arctan2(x, y))
    if bearing < 0:
        return bearing + 360
    return bearing


def get_arrows(locations, color="black", size=4, n_arrows=3, weight_arrow=3):
    Point = collections.namedtuple("Point", field_names=["lat", "lon"])
    p1 = Point(locations[0][0], locations[0][1])
    p2 = Point(locations[1][0], locations[1][1])
    rotation = get_bearing(p1, p2) - 90
    arrow_lats = numpy.linspace(p1.lat, p2.lat, n_arrows + 2)[1 : n_arrows + 1]
    arrow_lons = numpy.linspace(p1.lon, p2.lon, n_arrows + 2)[1 : n_arrows + 1]
    arrows = []
    for points in zip(arrow_lats, arrow_lons):
        arrows.append(
            folium.RegularPolygonMarker(
                location=points,
                color=color,
                weight=weight_arrow,
                fill=True,
                fill_color=color,
                fill_opacity=1,
                number_of_sides=3,
                radius=size,
                rotation=rotation,
            )
        )
    return arrows

# %%
lat_mean = df_sitios_bog["Lat"].mean()
lng_mean = df_sitios_bog["Lng"].mean()

bogota_map = folium.Map(location=[lat_mean, lng_mean], zoom_start=12, tiles="cartodbdark_matter")
for idx, row in df_sitios_bog.iterrows():
    if idx == "Bavaria SA.":
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=10, color="yellow", fill=True, fill_color="white", fill_opacity=0.6, popup=f"{idx}").add_to(bogota_map)
    else:
        folium.CircleMarker([row["Lat"], row["Lng"]], radius=5, color="blue", fill=True, fill_color="white", fill_opacity=0.8, popup=f"{idx}").add_to(bogota_map)

for i in range(len(ruta) - 1):
    coordinates = [
        df_sitios_bog.loc[ruta[i], ["Lat", "Lng"]].values.tolist(),
        df_sitios_bog.loc[ruta[i + 1], ["Lat", "Lng"]].values.tolist(),
    ]

    color = "gray"
    weight = 2

    pl = folium.PolyLine(coordinates, color=color, weight=weight)
    bogota_map.add_child(pl)

    arrows = get_arrows(locations=coordinates, color=color, size=2, n_arrows=1)
    for arrow in arrows:
        arrow.add_to(bogota_map)

bogota_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6ac958e2d750f1a9f935615db342bd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6ac958e2d750f1a9f935615db342bd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6ac958e2d750f1a9f935615db342bd8 = L.map(
#                 &quot;map_a6ac958e2d750f1a9f935615db342bd8&quot;,
#                 {
#                     center: [4.641263422780065, -74.09581026774993],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_531d48dac355ec2947942b46b5ac9867 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a6ac958e2d750f1a9f935615db342bd8);
#
#
#             var circle_marker_f32c5287f8e0dcfa1708a7ab85712f5a = L.circleMarker(
#                 [4.6152509440000795, -74.07153385099991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6ac958e2d750f1a9f935615db342bd8);
#
#
#         var popup_10d30061b882ffcdbf336e7751ea4e96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d9f2622bd0f477ce6ee613d59e2ed81 = $(`&lt;div id=&quot;html_6d9f2622bd0f477ce6ee613d59e2ed81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Escultura Nave Espacial&lt;/div&gt;`)[0];
#                 popup_10d30061b882ffcdbf336e7751ea4e96.setContent(html_6d9f2622bd0f477ce6ee613d59e2ed81);
#
#
#
#         circle_marker_f32c5287f8e0dcfa1708a7ab85712f5a.bindPopup(popup_10d30061b882ffcdbf336e7751ea4e96)
#         ;
#
#
#
#
#             var circle_marker_4c248d5f3f7abe7734d384246b6282b1 = L.circleMarker(
#                 [4.597386297000071, -74.07642138699993],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6ac958e2d750f1a9f935615db342bd8);
#
#
#         var popup_55379730360689f7ec39e73c13eba767 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e12ca3d7593dfb8e5c347d5533927b38 = $(`&lt;div id=&quot;html_e12ca3d7593dfb8e5c347d5533927b38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Tomas Cipriano de Mosquera&lt;/div&gt;`)[0];
#                 popup_55379730360689f7ec39e73c13eba767.setContent(html_e12ca3d7593dfb8e5c347d5533927b38);
#
#
#
#         circle_marker_4c248d5f3f7abe7734d384246b6282b1.bindPopup(popup_55379730360689f7ec39e73c13eba767)
#         ;
#
#
#
#
#             var circle_marker_d3e98a636633045f21444671fc444008 = L.circleMarker(
#                 [4.602078094000092, -74.06676842199994],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6ac958e2d750f1a9f935615db342bd8);
#
#
#         var popup_d850e5539f5931d5f54dfed31c25e156 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40dd609d61c5de0f15f70d27987db36e = $(`&lt;div id=&quot;html_40dd609d61c5de0f15f70d27987db36e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estatua Ricardo Palma&lt;/div&gt;`)[0];
#                 popup_d850e5539f5931d5f54dfed31c25e156.setContent(html_40dd609d61c5de0f15f70d27987db36e);
#
#
#
#         circle_
