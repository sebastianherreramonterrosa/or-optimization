# %% [markdown]
# ### **Minimización de coloreado de mapa**

# %% [markdown]
# Escribir un modelo de optimización que minimize el número de colores con los que se colorea las regiones de un mapa de tal forma que dos regiones adyacentes no tengan el misco color.
#
# ![image.png](attachment:image.png)

# %%
import pandas

# %%
df_colindancias = pandas.read_excel("./data/colindancias_colombia.xlsx", index_col=0)
df_colindancias
# Out:
#                                                     ANTIOQUIA  ATLANTICO  \
# ANTIOQUIA                                                   0          0
# ATLANTICO                                                   0          0
# SANTAFE DE BOGOTA D.C                                       0          0
# BOLIVAR                                                     1          1
# BOYACA                                                      1          0
# CALDAS                                                      1          0
# CAQUETA                                                     0          0
# CAUCA                                                       0          0
# CESAR                                                       0          0
# CORDOBA                                                     1          0
# CUNDINAMARCA                                                1          0
# CHOCO                                                       1          0
# ...
